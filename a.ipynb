# %%
pip install WordCloud
# Out:
# Collecting WordCloud
#   Using cached wordcloud-1.9.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (455 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
# Collecting pillow
#   Using cached Pillow-9.5.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.4 MB)
# Requirement already satisfied: numpy>=1.6.1 in /home/oh/workspace/venv/lib/python3.10/site-packages (from WordCloud) (1.24.3)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.4-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.39.4-py3-none-any.whl (1.0 MB)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/oh/workspace/venv/lib/python3.10/site-packages (from matplotlib->WordCloud) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/oh/workspace/venv/lib/python3.10/site-packages (from matplotlib->WordCloud) (23.1)
# Requirement already satisfied: six>=1.5 in /home/oh/workspace/venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->WordCloud) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, WordCloud
# Successfully installed WordCloud-1.9.1.1 contourpy-1.0.7 cycler-0.11.0 fonttools-4.39.4 kiwisolver-1.4.4 matplotlib-3.7.1 pillow-9.5.0 pyparsing-3.0.9
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install konlpy
# Out:
# Collecting konlpy
#   Using cached konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
# Requirement already satisfied: numpy>=1.6 in /home/oh/newenv/lib/python3.10/site-packages (from konlpy) (1.24.3)
# Collecting lxml>=4.1.0
#   Using cached lxml-4.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (7.1 MB)
# Collecting JPype1>=0.7.0
#   Using cached JPype1-1.4.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (465 kB)
# Requirement already satisfied: packaging in /home/oh/newenv/lib/python3.10/site-packages (from JPype1>=0.7.0->konlpy) (23.1)
# Installing collected packages: lxml, JPype1, konlpy
# Successfully installed JPype1-1.4.1 konlpy-0.6.0 lxml-4.9.2
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pillow
# Out:
# Requirement already satisfied: pillow in /home/oh/newenv/lib/python3.10/site-packages (7.1.2)
# Collecting pillow
#   Using cached Pillow-9.5.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.4 MB)
# Installing collected packages: pillow
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
# Successfully installed pillow-9.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from konlpy.tag import Okt
from PIL import Image
import numpy as np

with open('test.txt', 'r', encoding='utf-8') as f:
    text = f.read()
    
im = Image.open('/home/oh/workspace/다운로드.png')
mask_arr = np.array(im)

okt = Okt()
nouns = okt.nouns(text) # 명사만 추출

words = [n for n in nouns if len(n) > 1] # 단어의 길이가 1개인 것은 제외

c = Counter(words) # 위에서 얻은 words를 처리하여 단어별 빈도수 형태의 딕셔너리 데이터를 구함

wc = WordCloud(font_path='/home/oh/workspace/Font/malgunbd.ttf', width=400,mask = mask_arr, height=400, scale=2.0, max_font_size=250,
               background_color ='white')
gen = wc.generate_from_frequencies(c)
plt.figure()
plt.axis('off')
plt.imshow(gen)

# %%
def generate_wordcloud(file_path, image_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        text = f.read()

    im = Image.open(image_path)
    mask_arr = np.array(im)

    okt = Okt()
    nouns = okt.nouns(text)  # Extract only nouns

    words = [n for n in nouns if len(n) > 1]  # Exclude words with a length of 1

    c = Counter(words)  # Count the frequency of each word

    wc = WordCloud(font_path='/home/oh/workspace/Font/malgunbd.ttf', width=400, mask=mask_arr, height=400, scale=2.0,
                   max_font_size=250, background_color='white')
    gen = wc.generate_from_frequencies(c)

    plt.figure()
    plt.axis('off')
    plt.imshow(gen)
    plt.show()

# %%
generate_wordcloud('test.txt', '/home/oh/workspace/다운로드.png')

# %%
pip install pymysql
# Out:
# Collecting pymysql
#   Using cached PyMySQL-1.0.3-py3-none-any.whl (43 kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-1.0.3
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql

try:
    con = pymysql.connect(host='52.78.176.120', user='root', password='encore',  
                          port=3306, db='classicmodels', charset='utf8')
    cur = con.cursor()
except Exception as e:
    print (e)


cur.execute("show tables")
# Out:
# (2003, "Can't connect to MySQL server on '52.78.176.120' (timed out)")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 11
#       7 except Exception as e:
#       8     print (e)
# ---> 11 cur.execute("show tables")
#
# NameError: name 'cur' is not defined
